# %%
# import modules/libraries
import warnings 
warnings.simplefilter(action='ignore')
import osmnx as ox
import pandas as pd
import numpy as np
import geopandas as gpd
import time
from scipy import stats
import itertools
import os
import pickle
import geojson
from sqlalchemy import create_engine
import re
import sqlite3
from pathlib import Path
from shapely.geometry.polygon import Polygon
from shapely.geometry.multipolygon import MultiPolygon
import chardet
from scipy import spatial
from scipy.spatial import KDTree
from shapely import wkt

cwd = Path().resolve()
import chardet  # ! pip install chardet

# %%
def bundesland(k):
    if k == 'Sa':
        return 'Salzburg'
    elif k == 'St':
        return 'Steiermark'
    elif k == 'W':
        return 'Wien'
    elif k == 'T':
        return 'Tirol'
    elif k == 'V':
        return 'Vorarlberg'
    elif k == 'K':
        return 'Kärnten'
    elif k == 'O':
        return 'Oberösterreich'
    elif k == 'N':
        return 'Niederösterreich'
    elif k == 'B':
        return 'Burgenland'

# %%
with open(os.path.join(Path(cwd).parent, 'data', 'look-up', 'PLZ_BESTIMMUNGSORT-20220629.csv'), 'rb') as rawdata:
    result = chardet.detect(rawdata.read(10000))
tmp = pd.read_csv(os.path.join(Path(cwd).parent, 'data', 'look-up', 'PLZ_BESTIMMUNGSORT-20220629.csv'), sep=';', encoding=result['encoding'])
tmp.rename(columns={'GEMNR': 'GKZ'}, inplace=True)
print(f"PLZ_BESTIMMUNGSORT-20220629.csv len: {tmp.shape[0]}, unique PLZ: {tmp.PLZ.nunique()}, duplicates: {tmp.duplicated('PLZ', keep=False).sum()}")
#tmp.head(5)
# Out:
# PLZ_BESTIMMUNGSORT-20220629.csv len: 18867, unique PLZ: 2228, duplicates: 18432

# %%
# tmp[tmp.duplicated('PLZ', keep=False) == True]
df = tmp.groupby(['PLZ'], as_index=False).agg({'PLZ':'first', 'Bestimmungsort':'first', 'OKZ':'first', 'Ortschaft':'first', 'GKZ':'first', 'GEMNAM': 'first'})
print(f"len: {df2.shape[0]}, unique PLZ: {df2.PLZ.nunique()}, PLZ duplicates: {df2.duplicated('PLZ', keep=False).sum()}")
df.head(3)
# Out:
# len: 2228, unique PLZ: 2228, PLZ duplicates: 0
#     PLZ Bestimmungsort    OKZ          Ortschaft    GKZ GEMNAM
# 0  1010           Wien  17223  Wien,Innere Stadt  90001   Wien
# 1  1020           Wien  17224  Wien,Leopoldstadt  90001   Wien
# 2  1030           Wien  17225    Wien,Landstraße  90001   Wien

# %% [markdown]
# ## Problem (Why all the hassle)?
#
# PLZ_BESTIMMUNGSORT is missing the Ort and the Bundesland <br>
# PLZ_Verzeichnis is missing the **GKZ** which is needed for mapping to the **geojson** file.

# %%
with open(os.path.join(Path(cwd).parent, 'data', 'look-up', 'PLZ_BESTIMMUNGSORT-20220629.csv'), 'rb') as rawdata:
    result = chardet.detect(rawdata.read(10000))
plz = pd.read_csv(os.path.join(Path(cwd).parent, 'data', 'look-up', 'PLZ_Verzeichnis-20220629.csv'), sep=';', encoding=result['encoding'])
print(f"PLZ_Verzeichnis-20220629.csv len: {plz.shape[0]}, unique PLZ: {plz.PLZ.nunique()}, PLZ duplicates: {plz.duplicated('PLZ', keep=False).sum()}")
plz.head(3)
# Out:
# PLZ_Verzeichnis-20220629.csv len: 2521, unique PLZ: 2521, PLZ duplicates: 0
#     PLZ   Ort Bundesland   gültig ab gültig bis        NamePLZTyp  \
# 0  1000  Wien          W  01.08.2009        NaN      PLZ-Postfach
# 1  1004  Wien          W  01.01.1966        NaN  InteressentenPLZ
# 2  1006  Wien          W  01.02.2015        NaN      PLZ-Postfach
#
#   intern_extern adressierbar Postfach
# 0        extern         Nein       Ja
# 1        extern         Nein       Ja
# 2        extern         Nein       Ja

# %%
df = df.merge(plz[['PLZ','Ort', 'Bundesland']], on=['PLZ'], how='left')
print(f"Merge len: {df.shape[0]}, unique PLZ: {df.PLZ.nunique()}, duplicates: {df.duplicated('PLZ', keep=False).sum()}")
df['Bundesland'] = df.apply(lambda x: bundesland(x.Bundesland), axis=1)
df.to_csv(os.path.join(Path(cwd).parent, 'data', 'look-up', 'PLZ_LOOKUP_MERGE.csv'), encoding='utf-8', index=False)
df.tail(20)
# Out:
# Merge len: 2228, unique PLZ: 2228, duplicates: 0
#        PLZ              Bestimmungsort    OKZ            Ortschaft    GKZ  \
# 2208  9919                    Heinfels  16856           Panzendorf  70735
# 2209  9920                     Sillian  16875              Arnbach  70728
# 2210  9931             Außervillgraten  16780      Außervillgraten  70706
# 2211  9932             Innervillgraten  16795      Innervillgraten  70710
# 2212  9941                   Kartitsch  16809            Hollbruck  70713
# 2213  9942                Obertilliach  16852               Bergen  70721
# 2214  9943               Untertilliach  16882        Untertilliach  70733
# 2215  9951                       Ainet  16763                Ainet  70702
# 2216  9952         St. Johann im Walde  16867  St. Johann im Walde  70725
# 2217  9954                   Schlaiten  16874            Schlaiten  70727
# 2218  9961    Hopfgarten in Defereggen  16788               Dölach  70709
# 2219  9962      St. Veit in Defereggen  16868              Bruggen  70726
# 2220  9963     St. Jakob in Defereggen  16862           Außerrotte  70724
# 2221  9971          Matrei in Osttirol  16817                Bichl  70717
# 2222  9972                      Virgen  16883              Göriach  70734
# 2223  9974  Prägraten am Großvenediger  16857                Bichl  70723
# 2224  9981        Kals am Großglockner  16798                Arnig  70712
# 2225  9990              Nußdorf-Debant  16845               Debant  70719
# 2226  9991                     Dölsach  16781              Dölsach  70707
# 2227  9992          Iselsberg-Stronach  16796            Iselsberg  70711
#
#                           GEMNAM                       Ort Bundesland
# 2208                    Heinfels                  Heinfels      Tirol
# 2209                     Sillian                   Sillian      Tirol
# 2210             Außervillgraten           Außervillgraten      Tirol
# 2211             Innervillgraten           Innervillgraten      Tirol
# 2212                   Kartitsch                 Kartitsch      Tirol
# 2213                Obertilliach              Obertilliach      Tirol
# 2214               Untertilliach             Untertilliach      Tirol
# 2215                       Ainet                     Ainet      Tirol
# 2216         St. Johann im Walde       St. Johann im Walde      Tirol
# 2217                   Schlaiten                 Schlaiten      Tirol
# 2218    Hopfgarten in Defereggen  Hopfgarten in Defereggen      Tirol
# 2219      St. Veit in Defereggen    St. Veit in Defereggen      Tirol
# 2220     St. Jakob in Defereggen   St. Jakob in Defereggen      Tirol
# 2221          Matrei in Osttirol        Matrei in Osttirol      Tirol
# 2222                      Virgen                    Virgen      Tirol
# 2223  Prägraten am Großvenediger                 Prägraten      Tirol
# 2224        Kals am Großglockner                      Kals      Tirol
# 2225              Nußdorf-Debant            Nußdorf-Debant      Tirol
# 2226                     Dölsach                   Dölsach      Tirol
# 2227          Iselsberg-Stronach        Iselsberg-Stronach      Tirol
